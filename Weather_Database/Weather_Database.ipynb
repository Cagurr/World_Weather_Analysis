# %%
# Import modules
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import timeit
import requests
import time
from datetime import datetime
from citipy import citipy
from config import weather_api_key
import os

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 730

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
            
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | yumen
# Processing Record 2 of Set 1 | barrow
# Processing Record 3 of Set 1 | hervey bay
# Processing Record 4 of Set 1 | thompson
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | airai
# Processing Record 7 of Set 1 | chuy
# Processing Record 8 of Set 1 | bandarbeyla
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | hithadhoo
# Processing Record 11 of Set 1 | college
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 15 of Set 1 | kadoshkino
# Processing Record 16 of Set 1 | tocopilla
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | ahuimanu
# Processing Record 19 of Set 1 | tarves
# Processing Record 20 of Set 1 | berlevag
# Processing Record 21 of Set 1 | jumla
# Processing Record 22 of Set 1 | sioux lookout
# Processing Record 23 of Set 1 | atuona
# Processing Record 24 of Set 1 | luderitz
# Processing Record 25 of Set 1 | leningradskiy
# Processing Record 26 of Set 1 | vagur
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | dudinka
# Processing Record 29 of Set 1 | comodoro rivadavia
# Processing Record 30 of Set 1 | zbarazh
# Processing Record 31 of Set 1 | bluff
# Processing Record 32 of Set 1 | makakilo city
# Processing Record 33 of Set 1 | inzhavino
# Processing Record 34 of Set 1 | torbay
# Processing Record 35 of Set 1 | saint-philippe
# Processing Record 36 of Set 1 | ponta do sol
# Processing Record 37 of Set 1 | adrar
# Processing Record 38 of Set 1 | barra do bugres
# Processing Record 39 of Set 1 | ixtapa
# Processing Record 40 of Set 1 | dwarka
# Processing Record 41 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 1 | albany
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | rodrigues alves
# Processing Record 45 of Set 1 | tiksi
# Processing Record 46 of Set 1 | kodiak
# Processing Record 47 of Set 1 | constitucion
# Processing Record 48 of Set 1 | alice springs
# Processing Record 49 of Set 1 | new norfolk
# Processing Record 50 of Set 1 | la ronge
# Processing Record 1 of Set 2 | hobart
# Processing Record 2 of Set 2 | ribeira grande
# Processing Record 3 of Set 2 | butaritari
# Processing Record 4 of Set 2 | sarkand
# Processing Record 5 of Set 2 | rawalpindi
# Processing Record 6 of Set 2 | hermanus
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | hilo
# Processing Record 9 of Set 2 | saint anthony
# Processing Record 10 of Set 2 | orsha
# Processing Record 11 of Set 2 | port alfred
# Processing Record 12 of Set 2 | akola
# Processing Record 13 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 2 | matamoros
# Processing Record 15 of Set 2 | skibbereen
# Processing Record 16 of Set 2 | samana
# Processing Record 17 of Set 2 | talcahuano
# Processing Record 18 of Set 2 | ushuaia
# Processing Record 19 of Set 2 | maniitsoq
# Processing Record 20 of Set 2 | lasa
# Processing Record 21 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 2 | klaksvik
# Processing Record 23 of Set 2 | nerchinskiy zavod
# Processing Record 24 of Set 2 | shingu
# Processing Record 25 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 26 of Set 2 | bubaque
# Processing Record 27 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 2 | smithers
# Processing Record 29 of Set 2 | flin flon
# Processing Record 30 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 2 | nome
# Processing Record 32 of Set 2 | avarua
# Processing Record 33 of Set 2 | shebunino
# Processing Record 34 of Set 2 | yellowknife
# Processing Record 35 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 2 | fairbanks
# Processing Record 37 of Set 2 | georgetown
# Processing Record 38 of Set 2 | husavik
# Processing Record 39 of Set 2 | usakos
# Processing Record 40 of Set 2 | iqaluit
# Processing Record 41 of Set 2 | blackwater
# Processing Record 42 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 2 | bacuit
# City not found. Skipping...
# Processing Record 44 of Set 2 | vaini
# Processing Record 45 of Set 2 | jamestown
# Processing Record 46 of Set 2 | yerbogachen
# Processing Record 47 of Set 2 | ahipara
# Processing Record 48 of Set 2 | kabalo
# Processing Record 49 of Set 2 | kostomuksha
# Processing Record 50 of Set 2 | kaimur
# City not found. Skipping...
# Processing Record 1 of Set 3 | elban
# Processing Record 2 of Set 3 | santa cruz
# Processing Record 3 of Set 3 | shaoguan
# Processing Record 4 of Set 3 | beroroha
# Processing Record 5 of Set 3 | coleraine
# Processing Record 6 of Set 3 | beringovskiy
# Processing Record 7 of Set 3 | puerto ayora
# Processing Record 8 of Set 3 | marawi
# Processing Record 9 of Set 3 | tasiilaq
# Processing Record 10 of Set 3 | nanortalik
# Processing Record 11 of Set 3 | khani
# Processing Record 12 of Set 3 | port elizabeth
# Processing Record 13 of Set 3 | tabou
# Processing Record 14 of Set 3 | mar del plata
# Processing Record 15 of Set 3 | abha
# Processing Record 16 of Set 3 | mentok
# City not found. Skipping...
# Processing Record 17 of Set 3 | puri
# Processing Record 18 of Set 3 | geraldton
# Processing Record 19 of Set 3 | khash
# Processing Record 20 of Set 3 | vao
# Processing Record 21 of Set 3 | paka
# Processing Record 22 of Set 3 | broome
# Processing Record 23 of Set 3 | bambous virieux
# Processing Record 24 of Set 3 | iisalmi
# Processing Record 25 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 3 | bethel
# Processing Record 27 of Set 3 | kavaratti
# Processing Record 28 of Set 3 | presidencia roque saenz pena
# Processing Record 29 of Set 3 | yar-sale
# Processing Record 30 of Set 3 | senno
# Processing Record 31 of Set 3 | sabha
# Processing Record 32 of Set 3 | tiarei
# Processing Record 33 of Set 3 | nandu
# Processing Record 34 of Set 3 | cabo san lucas
# Processing Record 35 of Set 3 | owase
# Processing Record 36 of Set 3 | ancud
# Processing Record 37 of Set 3 | kundiawa
# Processing Record 38 of Set 3 | hasaki
# Processing Record 39 of Set 3 | kolokani
# Processing Record 40 of Set 3 | chokurdakh
# Processing Record 41 of Set 3 | aklavik
# Processing Record 42 of Set 3 | sibu
# Processing Record 43 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 3 | goure
# Processing Record 45 of Set 3 | sibolga
# Processing Record 46 of Set 3 | vila velha
# Processing Record 47 of Set 3 | opuwo
# Processing Record 48 of Set 3 | east london
# Processing Record 49 of Set 3 | pokhara
# Processing Record 50 of Set 3 | katsuura
# Processing Record 1 of Set 4 | clovis
# Processing Record 2 of Set 4 | cidreira
# Processing Record 3 of Set 4 | dombarovskiy
# Processing Record 4 of Set 4 | kamenka
# Processing Record 5 of Set 4 | solhan
# Processing Record 6 of Set 4 | evansville
# Processing Record 7 of Set 4 | esmeraldas
# Processing Record 8 of Set 4 | srednekolymsk
# Processing Record 9 of Set 4 | guerrero negro
# Processing Record 10 of Set 4 | lagoa
# Processing Record 11 of Set 4 | alyangula
# Processing Record 12 of Set 4 | namatanai
# Processing Record 13 of Set 4 | rach gia
# Processing Record 14 of Set 4 | turukhansk
# Processing Record 15 of Set 4 | saint george
# Processing Record 16 of Set 4 | namtsy
# Processing Record 17 of Set 4 | huarmey
# Processing Record 18 of Set 4 | namibe
# Processing Record 19 of Set 4 | mount gambier
# Processing Record 20 of Set 4 | evinayong
# Processing Record 21 of Set 4 | mecca
# Processing Record 22 of Set 4 | acari
# Processing Record 23 of Set 4 | santa lucia
# Processing Record 24 of Set 4 | egvekinot
# Processing Record 25 of Set 4 | damietta
# Processing Record 26 of Set 4 | saint-francois
# Processing Record 27 of Set 4 | chapais
# Processing Record 28 of Set 4 | ambon
# Processing Record 29 of Set 4 | viedma
# Processing Record 30 of Set 4 | kysyl-syr
# Processing Record 31 of Set 4 | awjilah
# Processing Record 32 of Set 4 | gigmoto
# Processing Record 33 of Set 4 | dikson
# Processing Record 34 of Set 4 | vestmannaeyjar
# Processing Record 35 of Set 4 | severo-kurilsk
# Processing Record 36 of Set 4 | longyearbyen
# Processing Record 37 of Set 4 | sakakah
# Processing Record 38 of Set 4 | jutai
# Processing Record 39 of Set 4 | chotila
# Processing Record 40 of Set 4 | buraydah
# Processing Record 41 of Set 4 | sterling
# Processing Record 42 of Set 4 | kruisfontein
# Processing Record 43 of Set 4 | castro
# Processing Record 44 of Set 4 | edgemoor
# Processing Record 45 of Set 4 | antissa
# City not found. Skipping...
# Processing Record 46 of Set 4 | atlantic city
# Processing Record 47 of Set 4 | supaul
# Processing Record 48 of Set 4 | zhigalovo
# Processing Record 49 of Set 4 | tura
# Processing Record 50 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 5 | beira
# Processing Record 2 of Set 5 | teluknaga
# Processing Record 3 of Set 5 | kidal
# Processing Record 4 of Set 5 | honningsvag
# Processing Record 5 of Set 5 | shenjiamen
# Processing Record 6 of Set 5 | pangnirtung
# Processing Record 7 of Set 5 | northam
# Processing Record 8 of Set 5 | batagay
# Processing Record 9 of Set 5 | calabozo
# Processing Record 10 of Set 5 | pisco
# Processing Record 11 of Set 5 | kahului
# Processing Record 12 of Set 5 | tautira
# Processing Record 13 of Set 5 | mahebourg
# Processing Record 14 of Set 5 | ostrovnoy
# Processing Record 15 of Set 5 | acarau
# Processing Record 16 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 17 of Set 5 | mogadishu
# Processing Record 18 of Set 5 | donegal
# Processing Record 19 of Set 5 | yirol
# City not found. Skipping...
# Processing Record 20 of Set 5 | itarema
# Processing Record 21 of Set 5 | bowen
# Processing Record 22 of Set 5 | nikolskoye
# Processing Record 23 of Set 5 | svetlogorsk
# Processing Record 24 of Set 5 | mana
# Processing Record 25 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 26 of Set 5 | golden
# Processing Record 27 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 5 | altamira
# Processing Record 29 of Set 5 | kraljevo
# Processing Record 30 of Set 5 | carnarvon
# Processing Record 31 of Set 5 | kollam
# Processing Record 32 of Set 5 | phan thiet
# Processing Record 33 of Set 5 | mackenzie
# Processing Record 34 of Set 5 | san patricio
# Processing Record 35 of Set 5 | berdigestyakh
# Processing Record 36 of Set 5 | vila franca do campo
# Processing Record 37 of Set 5 | dalby
# Processing Record 38 of Set 5 | saldanha
# Processing Record 39 of Set 5 | korla
# Processing Record 40 of Set 5 | norman wells
# Processing Record 41 of Set 5 | kutum
# Processing Record 42 of Set 5 | havre-saint-pierre
# Processing Record 43 of Set 5 | clyde river
# Processing Record 44 of Set 5 | esperance
# Processing Record 45 of Set 5 | novaya bryan
# Processing Record 46 of Set 5 | khatanga
# Processing Record 47 of Set 5 | narsaq
# Processing Record 48 of Set 5 | tuktoyaktuk
# Processing Record 49 of Set 5 | tazovskiy
# Processing Record 50 of Set 5 | jibuti
# Processing Record 1 of Set 6 | isla vista
# Processing Record 2 of Set 6 | waitati
# Processing Record 3 of Set 6 | lethem
# Processing Record 4 of Set 6 | palmerston
# Processing Record 5 of Set 6 | upernavik
# Processing Record 6 of Set 6 | isangel
# Processing Record 7 of Set 6 | lavrentiya
# Processing Record 8 of Set 6 | port moresby
# Processing Record 9 of Set 6 | aipe
# Processing Record 10 of Set 6 | haines junction
# Processing Record 11 of Set 6 | manta
# Processing Record 12 of Set 6 | atamanovka
# Processing Record 13 of Set 6 | doha
# Processing Record 14 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 6 | cooma
# Processing Record 16 of Set 6 | vostok
# Processing Record 17 of Set 6 | abonnema
# Processing Record 18 of Set 6 | luanda
# Processing Record 19 of Set 6 | cockburn town
# Processing Record 20 of Set 6 | mayumba
# Processing Record 21 of Set 6 | sao francisco do sul
# Processing Record 22 of Set 6 | arkhangelsk
# Processing Record 23 of Set 6 | wilmington
# Processing Record 24 of Set 6 | boende
# Processing Record 25 of Set 6 | narkevychi
# Processing Record 26 of Set 6 | port macquarie
# Processing Record 27 of Set 6 | krasnoselkup
# Processing Record 28 of Set 6 | port hardy
# Processing Record 29 of Set 6 | provideniya
# Processing Record 30 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 6 | kavieng
# Processing Record 32 of Set 6 | qandala
# Processing Record 33 of Set 6 | kununurra
# Processing Record 34 of Set 6 | baryshivka
# Processing Record 35 of Set 6 | pevek
# Processing Record 36 of Set 6 | hay river
# Processing Record 37 of Set 6 | cayenne
# Processing Record 38 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 6 | asau
# Processing Record 40 of Set 6 | kaitangata
# Processing Record 41 of Set 6 | arraial do cabo
# Processing Record 42 of Set 6 | voskresenskoye
# Processing Record 43 of Set 6 | bonthe
# Processing Record 44 of Set 6 | takoradi
# Processing Record 45 of Set 6 | codrington
# Processing Record 46 of Set 6 | murray bridge
# Processing Record 47 of Set 6 | umm kaddadah
# Processing Record 48 of Set 6 | mago
# Processing Record 49 of Set 6 | ranong
# Processing Record 50 of Set 6 | dossor
# Processing Record 1 of Set 7 | abu kamal
# Processing Record 2 of Set 7 | russell
# Processing Record 3 of Set 7 | ust-nera
# Processing Record 4 of Set 7 | nabire
# Processing Record 5 of Set 7 | ngunguru
# Processing Record 6 of Set 7 | verkh-chebula
# Processing Record 7 of Set 7 | miraflores
# Processing Record 8 of Set 7 | cherskiy
# Processing Record 9 of Set 7 | talnakh
# Processing Record 10 of Set 7 | buta
# Processing Record 11 of Set 7 | aswan
# Processing Record 12 of Set 7 | san felipe
# Processing Record 13 of Set 7 | maykor
# Processing Record 14 of Set 7 | lata
# Processing Record 15 of Set 7 | elliot lake
# Processing Record 16 of Set 7 | moranbah
# Processing Record 17 of Set 7 | los llanos de aridane
# Processing Record 18 of Set 7 | bata
# Processing Record 19 of Set 7 | ingham
# Processing Record 20 of Set 7 | santa rosa
# Processing Record 21 of Set 7 | ulladulla
# Processing Record 22 of Set 7 | tatawin
# Processing Record 23 of Set 7 | bedesa
# Processing Record 24 of Set 7 | beruwala
# Processing Record 25 of Set 7 | ust-kuyga
# Processing Record 26 of Set 7 | imbituba
# Processing Record 27 of Set 7 | borna
# Processing Record 28 of Set 7 | kawalu
# Processing Record 29 of Set 7 | yulara
# Processing Record 30 of Set 7 | mount isa
# Processing Record 31 of Set 7 | sivaki
# Processing Record 32 of Set 7 | fort nelson
# Processing Record 33 of Set 7 | galesong
# Processing Record 34 of Set 7 | kenora
# Processing Record 35 of Set 7 | champerico
# Processing Record 36 of Set 7 | lebu
# Processing Record 37 of Set 7 | bathsheba
# Processing Record 38 of Set 7 | lorengau
# Processing Record 39 of Set 7 | olafsvik
# Processing Record 40 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 41 of Set 7 | zhezkazgan
# Processing Record 42 of Set 7 | zyryanka
# Processing Record 43 of Set 7 | surt
# Processing Record 44 of Set 7 | barra do corda
# Processing Record 45 of Set 7 | scotts valley
# Processing Record 46 of Set 7 | sao filipe
# Processing Record 47 of Set 7 | aykhal
# Processing Record 48 of Set 7 | houston
# Processing Record 49 of Set 7 | vestmanna
# Processing Record 50 of Set 7 | baijiantan
# Processing Record 1 of Set 8 | ondorhaan
# City not found. Skipping...
# Processing Record 2 of Set 8 | nemuro
# Processing Record 3 of Set 8 | ilulissat
# Processing Record 4 of Set 8 | sitka
# Processing Record 5 of Set 8 | at-bashi
# Processing Record 6 of Set 8 | pochutla
# Processing Record 7 of Set 8 | praia da vitoria
# Processing Record 8 of Set 8 | leshukonskoye
# Processing Record 9 of Set 8 | vengerovo
# Processing Record 10 of Set 8 | ales
# Processing Record 11 of Set 8 | fortuna
# Processing Record 12 of Set 8 | eyl
# Processing Record 13 of Set 8 | saveh
# Processing Record 14 of Set 8 | san cristobal
# Processing Record 15 of Set 8 | myitkyina
# Processing Record 16 of Set 8 | mareeba
# Processing Record 17 of Set 8 | belmonte
# Processing Record 18 of Set 8 | marzuq
# Processing Record 19 of Set 8 | krasnogorsk
# Processing Record 20 of Set 8 | lamar
# Processing Record 21 of Set 8 | sabang
# Processing Record 22 of Set 8 | alofi
# Processing Record 23 of Set 8 | mayor pablo lagerenza
# Processing Record 24 of Set 8 | srivardhan
# Processing Record 25 of Set 8 | kismayo
# Processing Record 26 of Set 8 | loikaw
# Processing Record 27 of Set 8 | careiro da varzea
# Processing Record 28 of Set 8 | yining
# Processing Record 29 of Set 8 | te anau
# Processing Record 30 of Set 8 | raudeberg
# Processing Record 31 of Set 8 | colombo
# Processing Record 32 of Set 8 | rush
# Processing Record 33 of Set 8 | lixourion
# Processing Record 34 of Set 8 | klamath falls
# Processing Record 35 of Set 8 | kalmunai
# Processing Record 36 of Set 8 | inhambane
# Processing Record 37 of Set 8 | thinadhoo
# Processing Record 38 of Set 8 | hoa binh
# Processing Record 39 of Set 8 | altay
# Processing Record 40 of Set 8 | alblasserdam
# Processing Record 41 of Set 8 | barabinsk
# Processing Record 42 of Set 8 | camacha
# Processing Record 43 of Set 8 | harper
# Processing Record 44 of Set 8 | saskylakh
# Processing Record 45 of Set 8 | saint pete beach
# Processing Record 46 of Set 8 | chara
# Processing Record 47 of Set 8 | bacolod
# Processing Record 48 of Set 8 | tornio
# Processing Record 49 of Set 8 | lufilufi
# Processing Record 50 of Set 8 | orlik
# Processing Record 1 of Set 9 | nalut
# Processing Record 2 of Set 9 | sarangani
# Processing Record 3 of Set 9 | mao
# Processing Record 4 of Set 9 | rosarito
# Processing Record 5 of Set 9 | vangaindrano
# Processing Record 6 of Set 9 | vallenar
# Processing Record 7 of Set 9 | baghdad
# Processing Record 8 of Set 9 | ploemeur
# Processing Record 9 of Set 9 | westerland
# Processing Record 10 of Set 9 | hualmay
# Processing Record 11 of Set 9 | mayo
# Processing Record 12 of Set 9 | dongsheng
# Processing Record 13 of Set 9 | takaka
# Processing Record 14 of Set 9 | liseleje
# Processing Record 15 of Set 9 | panguna
# Processing Record 16 of Set 9 | koslan
# Processing Record 17 of Set 9 | bandar-e lengeh
# Processing Record 18 of Set 9 | shahrud
# Processing Record 19 of Set 9 | alsfeld
# Processing Record 20 of Set 9 | trebisacce
# Processing Record 21 of Set 9 | mandera
# Processing Record 22 of Set 9 | vardo
# Processing Record 23 of Set 9 | mildura
# Processing Record 24 of Set 9 | goderich
# Processing Record 25 of Set 9 | cervo
# Processing Record 26 of Set 9 | bell ville
# Processing Record 27 of Set 9 | papara
# Processing Record 28 of Set 9 | davila
# Processing Record 29 of Set 9 | nizhnyaya tavda
# Processing Record 30 of Set 9 | huambo
# Processing Record 31 of Set 9 | ganzhou
# Processing Record 32 of Set 9 | manga
# Processing Record 33 of Set 9 | faanui
# Processing Record 34 of Set 9 | lompoc
# Processing Record 35 of Set 9 | laguna
# Processing Record 36 of Set 9 | agadez
# Processing Record 37 of Set 9 | zeya
# Processing Record 38 of Set 9 | claresholm
# Processing Record 39 of Set 9 | umea
# Processing Record 40 of Set 9 | quatre cocos
# Processing Record 41 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 9 | turayf
# Processing Record 43 of Set 9 | mabopane
# Processing Record 44 of Set 9 | wichian buri
# Processing Record 45 of Set 9 | san ignacio
# Processing Record 46 of Set 9 | okhotsk
# Processing Record 47 of Set 9 | progreso
# Processing Record 48 of Set 9 | san ramon
# Processing Record 49 of Set 9 | orange walk
# Processing Record 50 of Set 9 | beyneu
# Processing Record 1 of Set 10 | shimoda
# Processing Record 2 of Set 10 | sept-iles
# Processing Record 3 of Set 10 | garmsar
# Processing Record 4 of Set 10 | serebryanyy bor
# Processing Record 5 of Set 10 | muros
# Processing Record 6 of Set 10 | andra
# Processing Record 7 of Set 10 | dubovskoye
# Processing Record 8 of Set 10 | victoria
# Processing Record 9 of Set 10 | otradnoye
# Processing Record 10 of Set 10 | muzhi
# Processing Record 11 of Set 10 | gamba
# Processing Record 12 of Set 10 | hammerfest
# Processing Record 13 of Set 10 | novikovo
# Processing Record 14 of Set 10 | uchiza
# Processing Record 15 of Set 10 | bukama
# Processing Record 16 of Set 10 | necochea
# Processing Record 17 of Set 10 | istisu
# Processing Record 18 of Set 10 | mahibadhoo
# Processing Record 19 of Set 10 | merrill
# Processing Record 20 of Set 10 | san carlos de bariloche
# Processing Record 21 of Set 10 | nurota
# Processing Record 22 of Set 10 | aksarka
# Processing Record 23 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 10 | madison
# Processing Record 25 of Set 10 | samarai
# Processing Record 26 of Set 10 | lensk
# Processing Record 27 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 10 | adelanto
# Processing Record 29 of Set 10 | barra do garcas
# Processing Record 30 of Set 10 | odweyne
# Processing Record 31 of Set 10 | acajutla
# Processing Record 32 of Set 10 | dharchula
# Processing Record 33 of Set 10 | shagamu
# Processing Record 34 of Set 10 | coihaique
# Processing Record 35 of Set 10 | darhan
# Processing Record 36 of Set 10 | boone
# Processing Record 37 of Set 10 | sogne
# Processing Record 38 of Set 10 | varlamovo
# Processing Record 39 of Set 10 | portland
# Processing Record 40 of Set 10 | broken hill
# Processing Record 41 of Set 10 | emerald
# Processing Record 42 of Set 10 | ware
# Processing Record 43 of Set 10 | roman
# Processing Record 44 of Set 10 | pereslavl-zalesskiy
# Processing Record 45 of Set 10 | nara
# Processing Record 46 of Set 10 | anadyr
# Processing Record 47 of Set 10 | obregon
# Processing Record 48 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 49 of Set 10 | bonfim
# Processing Record 50 of Set 10 | lubao
# Processing Record 1 of Set 11 | sao miguel do araguaia
# Processing Record 2 of Set 11 | muisne
# Processing Record 3 of Set 11 | omsukchan
# Processing Record 4 of Set 11 | kamariotissa
# Processing Record 5 of Set 11 | lagos
# Processing Record 6 of Set 11 | bambanglipuro
# Processing Record 7 of Set 11 | sarandi
# Processing Record 8 of Set 11 | okitipupa
# Processing Record 9 of Set 11 | urucui
# Processing Record 10 of Set 11 | bayshore gardens
# Processing Record 11 of Set 11 | ukiah
# Processing Record 12 of Set 11 | ternovka
# Processing Record 13 of Set 11 | kareli
# Processing Record 14 of Set 11 | yarmouth
# Processing Record 15 of Set 11 | lakatoro
# Processing Record 16 of Set 11 | haapiti
# Processing Record 17 of Set 11 | daru
# Processing Record 18 of Set 11 | baruun-urt
# Processing Record 19 of Set 11 | grindavik
# Processing Record 20 of Set 11 | massakory
# Processing Record 21 of Set 11 | greven
# Processing Record 22 of Set 11 | prince rupert
# Processing Record 23 of Set 11 | san pedro
# Processing Record 24 of Set 11 | lakes entrance
# Processing Record 25 of Set 11 | kathmandu
# Processing Record 26 of Set 11 | mitu
# Processing Record 27 of Set 11 | siloam springs
# Processing Record 28 of Set 11 | medea
# Processing Record 29 of Set 11 | banda aceh
# Processing Record 30 of Set 11 | souillac
# Processing Record 31 of Set 11 | sungaipenuh
# Processing Record 32 of Set 11 | ferme-neuve
# Processing Record 33 of Set 11 | visby
# Processing Record 34 of Set 11 | tuatapere
# Processing Record 35 of Set 11 | kissidougou
# Processing Record 36 of Set 11 | zeerust
# Processing Record 37 of Set 11 | borogontsy
# Processing Record 38 of Set 11 | mandalgovi
# Processing Record 39 of Set 11 | bengkulu
# Processing Record 40 of Set 11 | lokeren
# Processing Record 41 of Set 11 | kulhudhuffushi
# Processing Record 42 of Set 11 | rorvik
# Processing Record 43 of Set 11 | grand gaube
# Processing Record 44 of Set 11 | buy
# Processing Record 45 of Set 11 | copiapo
# Processing Record 46 of Set 11 | kendari
# Processing Record 47 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 11 | walvis bay
# Processing Record 49 of Set 11 | solnechnyy
# Processing Record 50 of Set 11 | hoquiam
# Processing Record 1 of Set 12 | nouadhibou
# Processing Record 2 of Set 12 | desaguadero
# Processing Record 3 of Set 12 | yarada
# Processing Record 4 of Set 12 | oranjemund
# Processing Record 5 of Set 12 | pangai
# Processing Record 6 of Set 12 | port blair
# Processing Record 7 of Set 12 | victor harbor
# Processing Record 8 of Set 12 | oktyabrskoye
# Processing Record 9 of Set 12 | ialibu
# Processing Record 10 of Set 12 | tamiahua
# Processing Record 11 of Set 12 | fort abbas
# Processing Record 12 of Set 12 | panama city
# Processing Record 13 of Set 12 | los algarrobos
# Processing Record 14 of Set 12 | sambava
# Processing Record 15 of Set 12 | coquimbo
# Processing Record 16 of Set 12 | la asuncion
# Processing Record 17 of Set 12 | folldal
# Processing Record 18 of Set 12 | sistranda
# Processing Record 19 of Set 12 | baoro
# Processing Record 20 of Set 12 | kandrian
# Processing Record 21 of Set 12 | aleksandrov gay
# Processing Record 22 of Set 12 | isoka
# Processing Record 23 of Set 12 | malmesbury
# Processing Record 24 of Set 12 | baykit
# Processing Record 25 of Set 12 | jacareacanga
# Processing Record 26 of Set 12 | buala
# Processing Record 27 of Set 12 | tezu
# Processing Record 28 of Set 12 | matata
# Processing Record 29 of Set 12 | aasiaat
# Processing Record 30 of Set 12 | jaena
# Processing Record 31 of Set 12 | praia
# Processing Record 32 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 33 of Set 12 | oktyabrskiy
# Processing Record 34 of Set 12 | manutuke
# Processing Record 35 of Set 12 | chabahar
# Processing Record 36 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 12 | labytnangi
# Processing Record 38 of Set 12 | bud
# Processing Record 39 of Set 12 | coronado
# Processing Record 40 of Set 12 | chimore
# Processing Record 41 of Set 12 | kirakira
# Processing Record 42 of Set 12 | rio gallegos
# Processing Record 43 of Set 12 | itoman
# Processing Record 44 of Set 12 | rockport
# Processing Record 45 of Set 12 | slavuta
# Processing Record 46 of Set 12 | nantucket
# Processing Record 47 of Set 12 | mopipi
# Processing Record 48 of Set 12 | iralaya
# Processing Record 49 of Set 12 | cotonou
# Processing Record 50 of Set 12 | moscow
# Processing Record 1 of Set 13 | shakiso
# Processing Record 2 of Set 13 | nago
# Processing Record 3 of Set 13 | gualaco
# Processing Record 4 of Set 13 | tiruvottiyur
# City not found. Skipping...
# Processing Record 5 of Set 13 | vieste
# Processing Record 6 of Set 13 | sangueya
# Processing Record 7 of Set 13 | galgani
# City not found. Skipping...
# Processing Record 8 of Set 13 | siguiri
# Processing Record 9 of Set 13 | tingo maria
# Processing Record 10 of Set 13 | aripuana
# Processing Record 11 of Set 13 | isla mujeres
# Processing Record 12 of Set 13 | dauriya
# Processing Record 13 of Set 13 | porto santo
# Processing Record 14 of Set 13 | nagar karnul
# Processing Record 15 of Set 13 | maldonado
# Processing Record 16 of Set 13 | augusto correa
# Processing Record 17 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 13 | deer lake
# Processing Record 19 of Set 13 | anajatuba
# Processing Record 20 of Set 13 | east wenatchee bench
# Processing Record 21 of Set 13 | canutama
# Processing Record 22 of Set 13 | hofn
# Processing Record 23 of Set 13 | irasan
# Processing Record 24 of Set 13 | palmeira das missoes
# Processing Record 25 of Set 13 | batak
# Processing Record 26 of Set 13 | honiara
# Processing Record 27 of Set 13 | hobyo
# Processing Record 28 of Set 13 | shakawe
# Processing Record 29 of Set 13 | komsomolskiy
# Processing Record 30 of Set 13 | avera
# Processing Record 31 of Set 13 | velykoploske
# Processing Record 32 of Set 13 | touros
# Processing Record 33 of Set 13 | ormara
# Processing Record 34 of Set 13 | paamiut
# Processing Record 35 of Set 13 | sola
# Processing Record 36 of Set 13 | caravelas
# Processing Record 37 of Set 13 | vegreville
# Processing Record 38 of Set 13 | deputatskiy
# Processing Record 39 of Set 13 | greenwood
# Processing Record 40 of Set 13 | sisimiut
# Processing Record 41 of Set 13 | wukari
# Processing Record 42 of Set 13 | paracuru
# Processing Record 43 of Set 13 | blahodatne
# Processing Record 44 of Set 13 | igrim
# Processing Record 45 of Set 13 | kungurtug
# Processing Record 46 of Set 13 | sicamous
# Processing Record 47 of Set 13 | faya
# Processing Record 48 of Set 13 | zhaoqing
# Processing Record 49 of Set 13 | batagay-alyta
# Processing Record 50 of Set 13 | soe
# Processing Record 1 of Set 14 | benjamin constant
# Processing Record 2 of Set 14 | ariyalur
# Processing Record 3 of Set 14 | rocha
# Processing Record 4 of Set 14 | gainesville
# Processing Record 5 of Set 14 | amahai
# Processing Record 6 of Set 14 | mouzakion
# City not found. Skipping...
# Processing Record 7 of Set 14 | naze
# Processing Record 8 of Set 14 | vanderhoof
# Processing Record 9 of Set 14 | antofagasta
# Processing Record 10 of Set 14 | lanja
# Processing Record 11 of Set 14 | hattiesburg
# Processing Record 12 of Set 14 | warrnambool
# Processing Record 13 of Set 14 | olinda
# Processing Record 14 of Set 14 | tiznit
# Processing Record 15 of Set 14 | sakhon nakhon
# Processing Record 16 of Set 14 | pacific grove
# Processing Record 17 of Set 14 | lyngseidet
# Processing Record 18 of Set 14 | usinsk
# Processing Record 19 of Set 14 | bima
# Processing Record 20 of Set 14 | wakefield
# Processing Record 21 of Set 14 | aldan
# Processing Record 22 of Set 14 | vila
# Processing Record 23 of Set 14 | pierre
# Processing Record 24 of Set 14 | cabedelo
# Processing Record 25 of Set 14 | eresos
# Processing Record 26 of Set 14 | riyadh
# Processing Record 27 of Set 14 | kargasok
# Processing Record 28 of Set 14 | eten
# Processing Record 29 of Set 14 | ivanava
# Processing Record 30 of Set 14 | port lincoln
# Processing Record 31 of Set 14 | vokhtoga
# Processing Record 32 of Set 14 | lagunas
# Processing Record 33 of Set 14 | kupang
# Processing Record 34 of Set 14 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 35 of Set 14 | gold coast
# Processing Record 36 of Set 14 | severo-yeniseyskiy
# Processing Record 37 of Set 14 | ligayan
# Processing Record 38 of Set 14 | maniwaki
# Processing Record 39 of Set 14 | asfi
# Processing Record 40 of Set 14 | lang suan
# Processing Record 41 of Set 14 | nioro
# Processing Record 42 of Set 14 | nova prata
# Processing Record 43 of Set 14 | bakchar
# Processing Record 44 of Set 14 | libreville
# Processing Record 45 of Set 14 | ratnagiri
# Processing Record 46 of Set 14 | salalah
# Processing Record 47 of Set 14 | margate
# Processing Record 48 of Set 14 | kanye
# Processing Record 49 of Set 14 | kokopo
# Processing Record 50 of Set 14 | dunedin
# Processing Record 1 of Set 15 | pa sang
# Processing Record 2 of Set 15 | kota kinabalu
# Processing Record 3 of Set 15 | dakar
# Processing Record 4 of Set 15 | koson
# Processing Record 5 of Set 15 | katherine
# Processing Record 6 of Set 15 | murud
# Processing Record 7 of Set 15 | san quintin
# Processing Record 8 of Set 15 | havelock
# Processing Record 9 of Set 15 | okha
# Processing Record 10 of Set 15 | gimli
# Processing Record 11 of Set 15 | atbasar
# Processing Record 12 of Set 15 | eirunepe
# Processing Record 13 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 14 of Set 15 | dalianwan
# Processing Record 15 of Set 15 | axim
# Processing Record 16 of Set 15 | shihezi
# Processing Record 17 of Set 15 | pauini
# Processing Record 18 of Set 15 | bom jesus do galho
# Processing Record 19 of Set 15 | valparaiso
# Processing Record 20 of Set 15 | salaga
# Processing Record 21 of Set 15 | sokoto
# Processing Record 22 of Set 15 | ewa beach
# Processing Record 23 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 24 of Set 15 | mutsu
# Processing Record 25 of Set 15 | wegrow
# Processing Record 26 of Set 15 | pitkyaranta
# Processing Record 27 of Set 15 | fangshan
# Processing Record 28 of Set 15 | mahon
# Processing Record 29 of Set 15 | kachikau
# City not found. Skipping...
# Processing Record 30 of Set 15 | tuma
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 691

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Yumen  40.2833   97.2000     81.61        15          88       12.71
# 1      Barrow  71.2906 -156.7887     37.42        87         100       11.50
# 2  Hervey Bay -25.2986  152.8535     58.64        93         100       10.04
# 3    Thompson  55.7435  -97.8558     62.76        72          75        6.91
# 4       Kapaa  22.0752 -159.3190     84.18        71          20       16.11
#
#   Country Current Description
# 0      CN     overcast clouds
# 1      US     overcast clouds
# 2      AU     overcast clouds
# 3      CA       broken clouds
# 4      US          few clouds

# %%
# Reorder the columns
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Yumen      CN  40.2833   97.2000     81.61        15          88
# 1      Barrow      US  71.2906 -156.7887     37.42        87         100
# 2  Hervey Bay      AU -25.2986  152.8535     58.64        93         100
# 3    Thompson      CA  55.7435  -97.8558     62.76        72          75
# 4       Kapaa      US  22.0752 -159.3190     84.18        71          20
#
#    Wind Speed Current Description
# 0       12.71     overcast clouds
# 1       11.50     overcast clouds
# 2       10.04     overcast clouds
# 3        6.91       broken clouds
# 4       16.11          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
